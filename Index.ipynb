# %% [markdown]
# # Welcome to CSC101

# %% [markdown]
# This is the first introductory lesson in which we will talk about the following concepts:
#
# - Installation of GNU C Compiler (GCC)
# - The first sample program
# - Installation of Sublime Text 2.0
# - Some other general ideas

# %%
print("Hello")
